# %%
import numpy as np
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler
boston=load_boston()
boston_df=pd.DataFrame(boston.data,columns=boston.feature_names)
boston_df['Price']=boston.target

# %%
boston_df._get_numeric_data()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
s_scaler = StandardScaler()
s_scaler.fit_transform(boston_df._get_numeric_data())[0:2]
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , -0.27259857, -0.14421743,
#          0.41367189, -0.12001342,  0.1402136 , -0.98284286, -0.66660821,
#         -1.45900038,  0.44105193, -1.0755623 ,  0.15968566],
#        [-0.41733926, -0.48772236, -0.59338101, -0.27259857, -0.74026221,
#          0.19427445,  0.36716642,  0.55715988, -0.8678825 , -0.98732948,
#         -0.30309415,  0.44105193, -0.49243937, -0.10152429]])

# %%
mm_scaler = MinMaxScaler()
mm_scaler.fit_transform(boston_df._get_numeric_data())[0:2]
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, 0.00000000e+00,
#         3.14814815e-01, 5.77505269e-01, 6.41606591e-01, 2.69203139e-01,
#         0.00000000e+00, 2.08015267e-01, 2.87234043e-01, 1.00000000e+00,
#         8.96799117e-02, 4.22222222e-01],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, 0.00000000e+00,
#         1.72839506e-01, 5.47997701e-01, 7.82698249e-01, 3.48961980e-01,
#         4.34782609e-02, 1.04961832e-01, 5.53191489e-01, 1.00000000e+00,
#         2.04470199e-01, 3.68888889e-01]])

# %%
sns.barplot(data=boston_df, x="AGE", y="Price")
plt.show()

# %%
sns.set_style("whitegrid")
sns.lineplot(data=boston_df, x="AGE", y="Price")
plt.show()

# %%
sns.catplot('Price', data=boston_df, kind="box")
plt.show()
# Out:
# /Users/nessimazoulay/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
boston_df.dropna()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
Q1 = np.percentile(boston.target, 25) #Q1

# %%
M = np.percentile(boston.target, 50) #Median

# %%
Q3 = np.percentile(boston.target, 75) #Q3

# %%
IQR = Q3 - Q1
IQR
# Out:
# 7.975000000000001

# %%
Q1 - 1.5 * IQR # Any data point below this result is a low outlier.
# Out:
# 5.0624999999999964

# %%
Q3 + 1.5 * IQR # Any data point above this result is a high outlier.
# Out:
# 36.962500000000006
